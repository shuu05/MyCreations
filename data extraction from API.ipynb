# %%
import pandas as pd

# %%
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=0877e7b1fce5ef12519e8851918ffb11&language=en-US&page=1')

# %%
df=pd.DataFrame(response.json()['results'])[['id','title','release_date','vote_average','overview','popularity']]

# %%
df
# Out:
#         id                         title release_date  vote_average  \
# 0    19404   Dilwale Dulhania Le Jayenge   1995-10-20           8.7
# 1   724089     Gabriel's Inferno Part II   2020-07-31           8.7
# 2      278      The Shawshank Redemption   1994-09-23           8.7
# 3      238                 The Godfather   1972-03-14           8.7
# 4   761053    Gabriel's Inferno Part III   2020-11-19           8.7
# 5   696374             Gabriel's Inferno   2020-05-29           8.7
# 6      424              Schindler's List   1993-11-30           8.6
# 7   615457                        Nobody   2021-03-18           8.6
# 8      240        The Godfather: Part II   1974-12-20           8.6
# 9   372058                    Your Name.   2016-08-26           8.6
# 10  791373  Zack Snyder's Justice League   2021-03-18           8.5
# 11     129                 Spirited Away   2001-07-20           8.5
# 12  441130                   Wolfwalkers   2020-10-26           8.5
# ...

# %%
df=pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range (1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=0877e7b1fce5ef12519e8851918ffb11&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','release_date','vote_average','overview','popularity']]
    df = df.append(temp_df,ignore_index=True)

# %%
df
# Out:
#           id                                  title release_date  \
# 0      19404            Dilwale Dulhania Le Jayenge   1995-10-20
# 1     724089              Gabriel's Inferno Part II   2020-07-31
# 2        278               The Shawshank Redemption   1994-09-23
# 3        238                          The Godfather   1972-03-14
# 4     761053             Gabriel's Inferno Part III   2020-11-19
# ...      ...                                    ...          ...
# 8555  455551                             The Recall   2017-06-02
# 8556  166424                         Fantastic Four   2015-08-05
# 8557  401546                             The Dinner   2017-05-05
# 8558   15268  Street Fighter: The Legend of Chun-Li   2009-02-27
# 8559   11692           The Adventures of Pluto Nash   2002-08-15
#
#       vote_average                                           overview  \
# 0              8.7  Raj is a rich, carefree, happy-go-lucky second...
# ...
